# %%
# let's import all required libraries
import selenium
from selenium import webdriver
import pandas as pd
import time
import warnings
warnings.filterwarnings('ignore')
from bs4 import BeautifulSoup
import requests

from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException,ElementNotInteractableException

# %% [markdown]
# ## 1. Scrape the details of most viewed videos on YouTube from Wikipedia.
#
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
#
# You need to find following details:
#
# A) Rank
#
# B) Name
#
# C) Artist
#
# D) Upload date
#
# E) Views

# %%
#let's first connect to web driver
driver=webdriver.Chrome(r'/Users/vikram/Downloads/chromedriver')

url='https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
driver.get(url)

rank=[]
song_name=[]
artist_name=[]
song_views=[]
upload_date=[]


Rank=driver.find_elements_by_xpath("//table[3][@class='wikitable sortable jquery-tablesorter']//tr//td[1]")
for i in Rank:
    rank.append(i.text)
    
song=driver.find_elements_by_xpath("//table[3][@class='wikitable sortable jquery-tablesorter']//tr//td[2]")
for i in song:
    song_name.append(i.text)

artist=driver.find_elements_by_xpath("//table[3][@class='wikitable sortable jquery-tablesorter']//tr//td[3]")
for i in artist:
    artist_name.append(i.text)    
    
views=driver.find_elements_by_xpath("//table[3][@class='wikitable sortable jquery-tablesorter']//tr//td[4]")
for i in views:
    song_views.append(i.text)    
    
upload=driver.find_elements_by_xpath("//table[3][@class='wikitable sortable jquery-tablesorter']//tr//td[5]")
for i in upload:
    upload_date.append(i.text)    

#Creating dataframe for scraped data

Youtube=pd.DataFrame({})
Youtube['Rank'] = rank
Youtube['Song Name'] = song_name
Youtube['Artist Name'] = artist_name
Youtube['Upload Date'] = upload_date
Youtube['Song Views'] = song_views

Youtube
# Out:
#     Rank                                        Song Name  \
# 0    NaN                            "Baby Shark Dance"[3]
# 1    NaN                                   "Despacito"[6]
# 2    NaN                       "Johny Johny Yes Papa"[12]
# 3    NaN                               "Shape of You"[13]
# 4    NaN                              "See You Again"[15]
# 5    NaN                                  "Bath Song"[20]
# 6    NaN                "Phonics Song with Two Words"[21]
# 7    NaN  "Learning Colors – Colorful Eggs on a Farm"[22]
# 8    NaN                                "Uptown Funk"[23]
# 9    NaN   "Masha and the Bear – Recipe for Disaster"[24]
# 10   NaN                              "Gangnam Style"[25]
# 11   NaN                          "Wheels on the Bus"[30]
# 12   NaN                             "Dame Tu Cosita"[31]
# 13   NaN                                      "Sugar"[32]
# 14   NaN                                       "Roar"[33]
# ...

# %% [markdown]
# ## 2. Scrape the details team India’s international fixtures from bcci.tv.
#
# Url = https://www.bcci.tv/.
#
# You need to find following details:
#
# A) Match title (I.e. 1st ODI)
#
# B) Series
#
# C) Place
#
# D) Date
#
# E) Time
#
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
#let's first connect to web driver
driver=webdriver.Chrome(r'/Users/vikram/Downloads/chromedriver')

url='https://www.bcci.tv/'
driver.get(url)


cookies_btn=driver.find_element_by_xpath("//button[@class='cookie__accept btn btn-primary']")
cookies_btn.click()

time.sleep(3)
driver.execute_script("window.scrollBy(0,500)")
time.sleep(5)


match_title=[]
Series_name=[]
Series_Place=[]
match_date=[]
match_Time=[]

match=driver.find_elements_by_xpath("//div[@class='match-time-place']//p//span[1]")
for i in match:
    match_title.append(i.text)
match_title[:5]

Series=driver.find_elements_by_xpath("//span[@class='ng-binding']")
for i in Series:
    Series_name.append(i.text)
    
Date=driver.find_elements_by_xpath("//h5[@class='ng-binding']")
for i in Date:
    match_date.append(i.text)
    
side=driver.find_element_by_xpath("//button[@class='slick-next slick-arrow']").click()
time.sleep(3)
   
Place=driver.find_elements_by_xpath("//div[@class='match-time-place']//p//span[2]")
for i in Place:
    Series_Place.append(i.text)
        
Time=driver.find_elements_by_xpath("//h5[@class='match-time ng-binding']")
for i in Time:
    match_Time.append(i.text)
    
    
#Creating dataframe for scraped data

Match=pd.DataFrame({})
Match['Title'] = match_title[:5]
Match['Series Name'] = Series_name[:5]
Match['Place'] = Series_Place[:5]
Match['Date'] = match_date[:5]
Match['Time'] = match_Time[:5]

Match
# Out:
#         Title                                 Series Name  \
# 0  1st T20I -  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 1  2nd T20I -  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 2  3rd T20I -  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 3  4th T20I -  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 4  5th T20I -  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
#
#                                                Place         Date         Time
# 0                              Arun Jaitley Stadium,   9 JUN 2022  7:30 PM IST
# 1                                  Barabati Stadium,  12 JUN 2022  7:30 PM IST
# 2  Dr YS Rajasekhara Reddy ACA-VDCA Cricket Stadium,  14 JUN 2022  7:30 PM IST
# 3            Saurashtra Cricket Association Stadium,  17 JUN 2022  7:30 PM IST
# 4                             M Chinnaswamy Stadium,  19 JUN 2022  7:30 PM IST

# %% [markdown]
# ## 3. Scrape the details of selenium exception from guru99.com. Url = https://www.guru99.com/
#
# You need to find following details:
#
# A) Name
#
# B) Description
#
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
#let's first connect to web driver
driver=webdriver.Chrome(r'/Users/vikram/Downloads/chromedriver')

url='https://www.guru99.com/'
driver.get(url)

url=driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[2]/div[1]/div/ul[1]/li[3]/a").click()

time.sleep(3)
driver.execute_script("window.scrollBy(0,4000)")
time.sleep(5)

tutorial=driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[1]/a").click()
time.sleep(3)

Exceptions_name=[]
Description=[]



Exceptions=driver.find_elements_by_xpath('//table[@class="table table-striped"]//tbody//tr//td[1]')
for i in Exceptions:
     Exceptions_name.append(i.text.replace("\n",""))


Describe=driver.find_elements_by_xpath('//table[@class="table table-striped"]//tbody//tr//td[2]')
for i in Describe:
     Description.append(i.text.replace("\n",""))

#Creating dataframe for scraped data

selenium=pd.DataFrame({})
selenium['Exceptions Names'] = Exceptions_name
selenium['Description'] = Description

selenium
# Out:
#                        Exceptions Names  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %% [markdown]
# ## 4. Scrape the details of State-wise GDP of India from statisticstime.com. Url = http://statisticstimes.com/
# You have to find following details:
#
# A) Rank
#
# B) State
#
# C) GSDP(18-19)
#
# D) GSDP(17-18)
#
# E) Share(2017)
#
# F) GDP($ billion)
#
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
#let's first connect to web driver
driver=webdriver.Chrome(r'/Users/vikram/Downloads/chromedriver')

url='http://statisticstimes.com/'
driver.get(url)

# %%
# Clicking on Economy button
driver.find_element_by_xpath("//div[@class='navbar']/div[2]/button").click()

# Clicking on India
driver.find_element_by_xpath("//div[@class='dropdown-content']/a[3]").click()
time.sleep(3)

# %%
# Clicking on GDP of Indian Economy
GDP = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/ul/li[1]/a').click()
time.sleep(3)

# %%
# Creating empty list
Rank = []
State = []
GSDP1 = []
GSDP2 = []
Share = []
GDP_billion = []

# Scraping Rank
try:
    for i in driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[1]"):
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append("_")
    
# Scraping State
try:
    for i in driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[2]"):
        State.append(i.text)
except NoSuchElementException:
    State.append("_")
    
# Scraping GSDP at current price (19-20)
try:
    for i in driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[3]"):
        GSDP1.append(i.text)
except NoSuchElementException:
    GSDP1.append("_")
    
# Scraping GSDP at current price (18-19)
try:
    for i in driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[4]"):
        GSDP2.append(i.text)
except NoSuchElementException:
    GSDP2.append("_")
    
# Scraping Share (18-19)
try:
    for i in driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[5]"):
        Share.append(i.text)
except NoSuchElementException:
    Share.append("_")
    
# Scraping GDP $ billion
try:
    for i in driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[6]"):
        GDP_billion.append(i.text)
except NoSuchElementException:
    GDP_billion.append("_")
    
# Creating DataFrame from the scraped data
GDP = pd.DataFrame({})
GDP['Rank'] = Rank
GDP['State'] = State
GDP['GSDP at current price (19-20)'] = GSDP1
GDP['GSDP at current price (18-19)'] = GSDP2
GDP['Share (18-19)'] = Share
GDP[' GDP($ billion)'] = GDP_billion
GDP
# Out:
#    Rank                      State GSDP at current price (19-20)  \
# 0     1                Maharashtra                             -
# 1     2                 Tamil Nadu                     1,845,853
# 2     3              Uttar Pradesh                     1,687,818
# 3     4                    Gujarat                             -
# 4     5                  Karnataka                     1,631,977
# ..  ...                        ...                           ...
# 61   29                     Sikkim                        28,391
# 62   30                   Nagaland                             -
# 63   31          Arunachal Pradesh                             -
# 64   32                    Mizoram                        24,424
# 65   33  Andaman & Nicobar Islands                             -
#
#    GSDP at current price (18-19) Share(18-19)  GDP($ billion)
# 0                      2,632,792       13.94%         399.921
# ...

# %% [markdown]
# ## 5) Scrape the details of trending repositories on Github.com.
#
# Url = https://github.com/
#
# You have to find the following details:
#
# A) Repository title
#
# B) Repository description
#
# C) Contributors count
#
# D) Language used
#
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
#let's first connect to web driver
driver=webdriver.Chrome(r'/Users/vikram/Downloads/chromedriver')

url='https://github.com/'
driver.get(url)

# %%
time.sleep(3)
#Getting explore button and clicking on it
explore = driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary").click()

trend= driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a")
trend.click()

Repository=[]
description=[]
Contributors=[]
Language=[]

title= driver.find_elements_by_xpath("//span[@class='text-normal']")
for i in title:
    Repository.append(i.text.replace("/",""))
repository=Repository


des=driver.find_elements_by_xpath("//p[@class='col-9 color-fg-muted my-1 pr-4']")
for i in des:
        description.append(i.text)


count=driver.find_elements_by_xpath("//div[@class='f6 color-fg-muted mt-2']/a[2]")
for i in count:
    Contributors.append(i.text)
Contributors
#Remove empty List from List
# using list comprehension
contributor = [ele for ele in Contributors if ele != []]
contributors=contibutor


lang=driver.find_elements_by_xpath("//span[@class='d-inline-block ml-0 mr-3']//span[2]")
for i in lang:
    Language.append(i.text)       


        
#DATA FRAMEING
Github=pd.DataFrame({})
Github['Repository title'] = repository[:20]
Github['Repository description'] = description[:20]
Github['Contributors count'] = contributors[:20]
Github['Language used'] = Language[:20]
Github
# Out:
#        Repository title                             Repository description  \
# 0         actualbudget               A local-first personal finance system
# 1         actualbudget                                     Actual's server
# 2               google   Wireit upgrades your npm scripts to make them ...
# 3        spacedriveapp   Spacedrive is an open source cross-platform fi...
# 4               ruanyf                                       科技爱好者周刊，每周五发布
# 5               gelove                叮咚买菜助手, 直接下载并运行, 不需要安装环境, 不需要下载源码！！！
# 6           gradio-app   Create UIs for your machine learning model in ...
# 7           Anduin2017   程序员在家做饭方法指南。Programmer's guide about how to co...
# 8         Pierian-Data   Course Files for Complete Python 3 Bootcamp Co...
# 9         RedisInsight                                        RedisInsight
# 10            ganelson   The core software distribution for the Inform ...
# ...

# %% [markdown]
# ## 6) Scrape the details of top 100 songs on billiboard.com.
#
# Url = https:/www.billboard.com/
#
# You have to find the following details:
#
# A) Song name
#
# B) Artist name
#
# C) Last week rank
#
# D) Peak rank
#
# E) Weeks on board
#
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
#let's first connect to web driver
driver=webdriver.Chrome(r'/Users/vikram/Downloads/chromedriver')

url='https:/www.billboard.com/'
driver.get(url)

# %%
#clicking on chart
chart = driver.find_element_by_xpath("/html/body/div[3]/header/div[1]/div/div/div[2]/div/nav/ul/li[1]/a")
chart.click()
#clicking on hot 100
hot100= driver.find_element_by_xpath("/html/body/div[3]/header/div[2]/div/nav/ul/li[1]/a")
hot100.click()

#making lists
Song_name=[]
artist_name=[]
Last_week_rank=[]
Peak_rank=[]
Weeks_on_board=[]



#scrapping song name
name= driver.find_elements_by_xpath("//div[@class='o-chart-results-list-row-container']//ul//li[4]//ul//li//h3")
for i in name:
    Song_name.append(i.text)

# scrapping artist name
artist= driver.find_elements_by_xpath("//div[@class='o-chart-results-list-row-container']//ul//li[4]//ul//li[1]//span")
for i in artist:
    artist_name.append(i.text)

#scrapping last week rank
lwrank= driver.find_elements_by_xpath("//div[@class='o-chart-results-list-row-container']//ul//li[4]//ul//li[4]//span")
for i in lwrank:
    Last_week_rank.append(i.text.split())

#Remove empty List from List
# using list comprehension
last_week_rank = [ele for ele in Last_week_rank if ele != []]

#scrapping peak rank
prank= driver.find_elements_by_xpath("//div[@class='o-chart-results-list-row-container']//ul//li[4]//ul//li[5]//span")
for i in prank:
    Peak_rank.append(i.text.split())
#Remove empty List from List
# using list comprehension
peak_rank = [ele for ele in Peak_rank if ele != []]

#scrapping weeks on board
wboard= driver.find_elements_by_xpath("//div[@class='o-chart-results-list-row-container']//ul//li[4]//ul//li[6]//span")
for i in wboard:
    Weeks_on_board.append(i.text)

#DATA FRAMEING
Billboard=pd.DataFrame({})
Billboard['Song name'] = Song_name
Billboard['Artist name'] = artist_name
Billboard['Last week rank'] = last_week_rank
Billboard['Peak rank'] = peak_rank
Billboard['Weeks on board'] = Weeks_on_board

Billboard
# Out:
#        Song name               Artist name Last week rank Peak rank  \
# 0      As It Was              Harry Styles            [2]       [1]
# 1    First Class               Jack Harlow            [1]       [1]
# 2     Heat Waves             Glass Animals            [3]       [1]
# 3     Big Energy                     Latto            [4]       [3]
# 4          Enemy     Imagine Dragons X JID            [5]       [5]
# ..           ...                       ...            ...       ...
# 95       P Power     Gunna Featuring Drake           [91]      [24]
# 96  Money So Big                      Yeat            [-]      [95]
# 97  Blick Blick!   Coi Leray & Nicki Minaj           [95]      [37]
# 98  Fall In Love          Bailey Zimmerman            [-]      [99]
# 99  X Ultima Vez  Daddy Yankee & Bad Bunny           [99]      [73]
#
#    Weeks on board
# 0               3
# 1               2
# 2              66
# 3              26
# 4              22
# ..            ...
# ...

# %% [markdown]
# ## 7) Scrape the details of Data science recruiters from naukri.com. Url = https://www.naukri.com/
#
# You have to find the following details:
#
# A) Name
#
# B) Designation
#
# C) Company
#
# D) Skills they hire for
#
# E) Location
#
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and click on search. All this should be done through code.

# %%
#let's first connect to web driver
driver=webdriver.Chrome(r'/Users/vikram/Downloads/chromedriver')

url='https://www.naukri.com/hr-recruiters-consultants'
driver.get(url)

# %%
# Fetching search button, sending keys and clicking on it
search = driver.find_element_by_xpath("//div[@class='inpWrap']//input") 
search.send_keys("Data science ")           
btn = driver.find_element_by_xpath("//button[@class='fl qsbSrch blueBtn']").click()     
time.sleep(3)

# %%
#Creating empty lists
Name = []
Designation = []
Company = []
Skills = []
Location = []

#Scraping data of Names
for i in driver.find_elements_by_xpath("//span[@class='fl ellipsis']"):
    Name.append(i.text)
time.sleep(3)


#Scraping data of Designation
for i in driver.find_elements_by_xpath("//span[@class='ellipsis clr']"):
    Designation.append(i.text)
time.sleep(3)

#Scraping data of company name
for i in driver.find_elements_by_xpath("//div[@class='vcard']//p[1]/a[2]"):
    Company.append(i.text)
time.sleep(3)
    
#scraping data of Skills 
for i in driver.find_elements_by_xpath("//div[@class='hireSec highlightable']"):
    try:
        if i.text == "Not Specified": raise NoSuchElementException
        Skills.append(i.text)
    except NoSuchElementException:
        Skills.append('-')
    time.sleep(3)

#Scraping data of locations
for i in driver.find_elements_by_xpath("//div[@class='vcard']//p[1]//span"):
    Location.append(i.text)
time.sleep(3)

# Creating dataframe for scraped data
Naukri=pd.DataFrame({})
Naukri['Name'] = Name[:50]
Naukri['Designation'] = Designation[:50]
Naukri['Company'] = Company[:50]
Naukri['Skills'] = Skills[:50]
Naukri['Location'] = Location[:50]
Naukri
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                 Priyanka Akiri
# 11                                Kalpana Dumpala
# 12                                        Mubarak
# 13                                 Kushal Rastogi
# 14                             Mahesh Babu Channa
# 15                                Sakshi Chhikara
# 16                                   Kapil Devang
# 17                                    Ruchi Dhote
# ...

# %% [markdown]
# ## 8) Scrape the details of Highest selling novels.
#
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey- compare/
#
# You have to find the following details:
#
# A) Book name
#
# B) Author name
#
# C) Volumes sold
#
# D) Publisher
#
# E) Genre

# %%
#let's first connect to web driver
driver=webdriver.Chrome(r'/Users/vikram/Downloads/chromedriver')

url="https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare"
driver.get(url)

# %%
Book_name=[]
Author_name=[]
Volumes_sold=[]
Publisher=[]
Genre=[]

#scrapping book name
name= driver.find_elements_by_xpath("//tr//td[2][@class='left']")
for i in name:
    Book_name.append(i.text)
    
#scrapping author name
aname= driver.find_elements_by_xpath("//tr//td[3][@class='left']")
for i in aname:
    Author_name.append(i.text)
    
#scrapping volume sold
sold= driver.find_elements_by_xpath("//tr//td[4][@class='left']")
for i in sold:
    Volumes_sold.append(i.text)
    
#scrappiing piblisher
pub= driver.find_elements_by_xpath("//tr//td[5][@class='left']")
for i in pub:
    Publisher.append(i.text)
    
#scrapping genre
g= driver.find_elements_by_xpath("//tr//td[6][@class='last left']")
for i in g:
    Genre.append(i.text)

#DATA FRAMEING
guardian=pd.DataFrame({})
guardian['Book name'] = Book_name
guardian['Author name'] = Author_name
guardian['Volumes_sold'] = Volumes_sold
guardian['Publisher'] = Publisher
guardian['Genre'] = Genre

guardian
# Out:
#                                             Book name       Author name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes_sold        Publisher                        Genre
# ...

# %% [markdown]
# ## 9) Scrape the details most watched tv series of all time from imdb.com. Url = https://www.imdb.com/list/ls095964455/
#
# You have to find the following details:
#
# A) Name
#
# B) Year span
#
# C) Genre
#
# D) Run time
#
# E) Ratings
#
# F) Votes

# %%
#let's first connect to web driver
driver=webdriver.Chrome(r'/Users/vikram/Downloads/chromedriver')

url="https://www.imdb.com/list/ls095964455/"
driver.get(url)

# %%
Series_name=[]
year_span=[]
Genre=[]
runtime=[]
Ratings=[]
Votes=[]

#scrapping name of series
name= driver.find_elements_by_xpath("//div//div[1]//div[2]//h3//a")
for i in name:
    Series_name.append(i.text)

#scrapping year span
year= driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']")
for i in year:
    year_span.append(i.text)
    
#scrapping Genre
g= driver.find_elements_by_xpath("//span[@class='genre']")
for i in g:
    Genre.append(i.text) 
    
#scrapping runtime
r= driver.find_elements_by_xpath("//span[@class='runtime']")
for i in r:
    runtime.append(i.text)
    
#scrapping Ratings
ra= driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']//span[2]")
for i in ra:
    Ratings.append(i.text)
    
#scrapping votes
v= driver.find_elements_by_xpath("//div[@class='lister-item mode-detail']//p[4]//span[2]")
for i in v:
    Votes.append(i.text)    
    
#making dataframe
series=pd.DataFrame({})
series['Series Name'] = Series_name
series['Year Span'] = year_span
series['Genre'] = Genre
series['Runtime'] = runtime
series['Ratings'] = Ratings
series['Votes'] = Votes

series
# Out:
#                        Series Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#     Runtime Ratings      Votes
# 0    57 min     9.2  1,980,206
# ...

# %% [markdown]
# ### 10) Details of Datasets from UCI machine learning repositories. Url = https://archive.ics.uci.edu/
# You have to find the following details:
#
# A) Dataset name
#
# B) Data type
#
# C) Task
#
# D) Attribute type
#
# E) No of instances
#
# F) No of attribute
#
# G) Year
#
# Note: - from the home page you have to go to the ShowAllDataset page through code.

# %%
#let's first connect to web driver
driver=webdriver.Chrome(r'/Users/vikram/Downloads/chromedriver')

url="https://archive.ics.uci.edu/"
driver.get(url)

# %%
# Finding view all dataset button from the webpage
viewall_dataset = driver.find_element_by_xpath("//tbody[1]//tr/td[2]/span[2]/a")    
page_url = viewall_dataset.get_attribute("href")
driver.get(page_url)
time.sleep(3)

# %%
# Fetching page urls of all datasets 
view_list = driver.find_element_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[1]/tbody/tr/td[2]/p/a")  
list_url = view_list.get_attribute("href")           
driver.get(list_url)
time.sleep(3)

# %%
# Fetching urls for each dataset
dataset_url = driver.find_elements_by_xpath("//p[@class='normal']//b//a")    

urls = []     
for i in dataset_url:
    urls.append(i.get_attribute("href"))

# %%
#Creating empty lists
Dataset_name = []
Data_type = []
Task = []
Attribute_type = []
No_of_instances = []
No_of_attributes = []
Year = []

for i in urls:
    driver.get(i)
    time.sleep(3)
    
    #Scraping Dataset name
    try: 
        dataset_name = driver.find_element_by_xpath("//span[@class='heading']")
        Dataset_name.append(dataset_name.text)
    except NoSuchElementException:
        Dataset_name.append('-')
    time.sleep(2)
    
    #Scraping data type
    try:
        data_type = driver.find_element_by_xpath("//table[@border='1']//tbody/tr/td[2]")
        if data_type.text == "N/A": raise NoSuchElementException
        Data_type.append(data_type.text)
    except NoSuchElementException:
        Data_type.append('-')
    time.sleep(2)
    
    #scraping Task
    try:
        task = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[3]/td[2]")
        if task.text == "N/A": raise NoSuchElementException
        Task.append(task.text)
    except NoSuchElementException:
        Task.append('-')
    time.sleep(2)
    # Scraping Attribute type
    try:
        attribute_type = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[2]")
        if attribute_type.text == "N/A": raise NoSuchElementException
        Attribute_type.append(attribute_type.text)
    except NoSuchElementException:
        Attribute_type.append('-')
    time.sleep(2)
    
    # Scraping No of instances
    try:
        instances = driver.find_element_by_xpath("//table[@border='1']//tbody/tr/td[4]")
        if instances.text == "N/A": raise NoSuchElementException
        No_of_instances.append(instances.text)
    except NoSuchElementException:
        No_of_instances.append('-')
    time.sleep(2)
    
    # Scraping No of attributes
    try:
        attribute = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[4]")
        if attribute.text == "N/A": raise NoSuchElementException
        No_of_attributes.append(attribute.text)
    except NoSuchElementException:
        No_of_attributes.append('-')
    time.sleep(2)
    
    # Scraping year
    try:
        year = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[6]")
        if year.text == "N/A": raise NoSuchElementException
        Year.append(year.text[:4])
    except NoSuchElementException:
        Year.append('-')
    time.sleep(2)

# %%
# Creating dataframe for scraped data
ML=pd.DataFrame({})
ML['Data Name'] = Dataset_name
ML['Data Type'] = Data_type
ML['Task'] = Task
ML['Attribute type'] = Attribute_type
ML['No of instance'] = No_of_instances
ML['No of attributes'] = No_of_attributes
ML['Year'] = Year
ML
# Out:
#                                              Data Name  \
# 0         2.4 GHZ Indoor Channel Measurements Data Set
# 1    3D Road Network (North Jutland, Denmark) Data Set
# 2                                  3W dataset Data Set
# 3                          9mers from cullpdb Data Set
# 4    : Simulated Data set of Iraqi tourism places D...
# ..                                                 ...
# 617  Youtube cookery channels viewers comments in H...
# 618     YouTube Multiview Video Games Dataset Data Set
# 619                   YouTube Spam Collection Data Set
# 620                           Z-Alizadeh Sani Data Set
# 621                                       Zoo Data Set
#
#                      Data Type                        Task  \
# 0                 Multivariate              Classification
# 1             Sequential, Text      Regression, Clustering
# 2    Multivariate, Time-Series  Classification, Clustering
# 3                   Sequential  Classification, Regression
# ...
